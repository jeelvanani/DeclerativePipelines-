# %% [markdown]
# this is the notebook that explains and give facts about the databricks declarative pipelines.

# %% [markdown]
# # Key Components in DLT

# %% [markdown]
# 1. streaming tables
#
# --> streaming tables are the tables which automatically updates the data as soon as new data is pushed in source. no need fpr batches to push

# %% [markdown]
# 2. materialized views
#
# --> it is the normal view with the stored result.
#
# usually the view is just a SQL query. with the materialized view. you can also store result of that particular query.

# %% [markdown]
# 3. views
#
# --> this is just normal view which just stores the query

# %% [markdown]
# we will create a streaming table with the delta live table
